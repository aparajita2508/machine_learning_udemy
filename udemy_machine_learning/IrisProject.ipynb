# %% [markdown]
# # Iris Project

# %% [markdown]
# # Data exploration and analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes = True)
# %matplotlib inline

# %%
df = pd.read_csv("Iris/iris.data", header = -1)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.columns = ['sepal_length_in_cm', 'sepal_width_in_cm', 'petal_length_in_cm', 'petal_width_in_cm', 'species']
df.head()
# Out:
#    sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal_width_in_cm      species
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa

# %%
df.describe() # Standard daviation
# Out:
#        sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# count          150.000000         150.000000          150.000000
# mean             5.843333           3.054000            3.758667
# std              0.828066           0.433594            1.764420
# min              4.300000           2.000000            1.000000
# 25%              5.100000           2.800000            1.600000
# 50%              5.800000           3.000000            4.350000
# 75%              6.400000           3.300000            5.100000
# max              7.900000           4.400000            6.900000
#
#        petal_width_in_cm
# count         150.000000
# mean            1.198667
# std             0.763161
# min             0.100000
# 25%             0.300000
# 50%             1.300000
# 75%             1.800000
# max             2.500000

# %%
df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.groupby('species').size()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# # Visualisation

# %%
sns.pairplot(df, hue= "species", size = 3)

# %%
plt.subplot(2,2,1)
sns.violinplot(x = 'species', y = 'sepal_length_in_cm', hue = "species", data = df)
plt.subplot(2,2,2)
sns.violinplot(x = 'species', y = 'petal_length_in_cm', data = df)
plt.subplot(2,2,3)
sns.violinplot(x = 'species', y = 'sepal_width_in_cm', data = df)
plt.subplot(2,2,4)
sns.violinplot(x = 'species', y = 'petal_width_in_cm', data = df)

# %%
df.boxplot(by='species', figsize = (12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a173f8050>,
# ...
#       dtype=object)

# %%
pd.scatter_matrix(df, figsize = (12,8))
plt.show()
# Out:
# /Users/aparajita/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Key points
# ###### The data is in the form of table,
# ###### Features in the form of matrix,
# ###### Label or target array (target/label)
# ###### Each row is a sample

# %% [markdown]
# # Supervised Learning: Linear Regression

# %%
x = 100 * np.random.rand(100)
y = -5 *x + np.random.rand(100)
plt.scatter(x,y, marker='*')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept=True)
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Feature matrix
X = x.reshape(-1,1)
X.shape
# Out:
# (100, 1)

# %%
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.coef_
# Out:
# array([-5.00081031])

# %%
model.intercept_
# Out:
# 0.5528948950115478

# %%
x_fit = np.linspace(-1,11)
X_fit = x.reshape(-1,1)
y_fit = model.predict(X_fit)
plt.scatter(x,y,)
plt.plot(X_fit,y_fit)
plt.show()
